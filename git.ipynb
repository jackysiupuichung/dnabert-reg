# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/My Drive/master_thesis/notebooks/
# Out:
# /content/drive/My Drive/master_thesis/notebooks

# %%
ls
# Out:
# DNABERT_reg_CNN.ipynb  findmotifs.ipynb  inputparser.ipynb
# DNABERT_reg.ipynb      git.ipynb         regression_model.ipynb

# %%
# !git init
# Out:
# Initialized empty Git repository in /content/drive/My Drive/master_thesis/notebooks/.git/

# %%
# !git remote add origin https://{DNABERT-reg}:{glpat-yejbecfaWZCw9LM9gyox}@gitlab.com/{puichung.siu}/{DNABERT-reg}.git
# !git remote -v
# Out:
# origin	https://{DNABERT-reg}:{glpat-yejbecfaWZCw9LM9gyox}@gitlab.com/{puichung.siu}/{DNABERT-reg}.git (fetch)
# origin	https://{DNABERT-reg}:{glpat-yejbecfaWZCw9LM9gyox}@gitlab.com/{puichung.siu}/{DNABERT-reg}.git (push)

# %%
# !git add .
# !git commit -m 'First commit'
# Out:
# *** Please tell me who you are.
#
# Run
#
#   git config --global user.email "you@example.com"
#   git config --global user.name "Your Name"
#
# to set your account's default identity.
# Omit --global to set the identity only in this repository.
#
# fatal: unable to auto-detect email address (got 'root@137bbf3662c3.(none)')

# %%
  git config user.email "puichung.siu@wur.nl"
  git config user.name "jackysiu"
# Out:
#   File "<ipython-input-17-1042a8bf3b85>", line 1
#     git config user.email "puichung.siu@wur.nl"
#              ^
# SyntaxError: invalid syntax
