# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd /content/drive/My Drive/master_thesis/notebooks/
# Out:
# /content/drive/My Drive/master_thesis/notebooks

# %%
ls
# Out:
# 'DNABERT_reg(analysis).ipynb'   git.ipynb           regression_model.ipynb
#  findmotifs.ipynb               inputparser.ipynb

# %%
# !git init
# Out:
# Reinitialized existing Git repository in /content/drive/My Drive/master_thesis/notebooks/.git/

# %%
  # !git config user.email "puichung.siu@wur.nl"
  # !git config user.name "jackysiu"

# %%
# !git remote add origin https://DNABERT-reg:glpat-yejbecfaWZCw9LM9gyox@git.wur.nl/puichung.siu/dnabert-reg.git
# !git remote -v
# Out:
# fatal: remote origin already exists.
# origin	https://DNABERT-reg:glpat-yejbecfaWZCw9LM9gyox@git.wur.nl/puichung.siu/dnabert-reg.git (fetch)
# origin	https://DNABERT-reg:glpat-yejbecfaWZCw9LM9gyox@git.wur.nl/puichung.siu/dnabert-reg.git (push)

# %%
#!git remote remove origin

# %%
# !git add .
# !git commit -m 'First commit'
# Out:
# [master 152561a] First commit
#  8 files changed, 5 insertions(+), 7 deletions(-)
#  create mode 100644 DNABERT_reg(analysis).ipynb
#  delete mode 100644 DNABERT_reg.ipynb
#  delete mode 100644 DNABERT_reg_CNN.ipynb
#  rewrite findmotifs.ipynb (97%)
#  rewrite inputparser.ipynb (98%)
#  delete mode 100644 motif_analysis.ipynb
#  rewrite regression_model.ipynb (98%)

# %%
# !git push origin master
# Out:
# Counting objects: 24, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (24/24), done.
# Writing objects: 100% (24/24), 946.70 KiB | 6.48 MiB/s, done.
# Total 24 (delta 9), reused 0 (delta 0)
# remote:
# remote: To create a merge request for master, visit:
# remote:   https://git.wur.nl/puichung.siu/dnabert-reg/-/merge_requests/new?merge_request%5Bsource_branch%5D=master
# remote:
# To https://git.wur.nl/puichung.siu/dnabert-reg.git
#  * [new branch]      master -> master

# %% [markdown]
# https://libinruan.gitlab.io/2020/02/07/How-to-Push-from-Colab-to-GitLab-A-Personal-Access-Token-Approach/
