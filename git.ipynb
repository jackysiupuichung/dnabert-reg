# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/My Drive/master_thesis/notebooks/
# Out:
# /content/drive/My Drive/master_thesis/notebooks

# %%
ls
# Out:
# DNABERT_reg_CNN.ipynb  git.ipynb             regression_model.ipynb
# DNABERT_reg.ipynb      inputparser.ipynb
# findmotifs.ipynb       motif_analysis.ipynb

# %%
# !git init
# Out:
# Reinitialized existing Git repository in /content/drive/My Drive/master_thesis/notebooks/.git/

# %%
  # !git config user.email "puichung.siu@wur.nl"
  # !git config user.name "jackysiu"

# %%
# !git remote add origin https://DNABERT-reg:glpat-yejbecfaWZCw9LM9gyox@git.wur.nl/puichung.siu/dnabert-reg.git
# !git remote -v

# %%
#!git remote remove origin

# %%
# !git add .
# !git commit -m 'First commit'
# Out:
# [master 2873baf] First commit
#  4 files changed, 4 insertions(+), 3 deletions(-)
#  rewrite DNABERT_reg.ipynb (96%)
#  rewrite findmotifs.ipynb (95%)
#  rewrite git.ipynb (97%)
#  create mode 100644 motif_analysis.ipynb

# %%
# !git push origin master
# Out:
# fatal: 'origin' does not appear to be a git repository
# fatal: Could not read from remote repository.
#
# Please make sure you have the correct access rights
# and the repository exists.

# %% [markdown]
# https://libinruan.gitlab.io/2020/02/07/How-to-Push-from-Colab-to-GitLab-A-Personal-Access-Token-Approach/
